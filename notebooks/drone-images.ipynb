# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np
import rasterio as rs
from osgeo import gdal, ogr

# %%
main_path = "/home/amir/projects/data/lake_victoria"
data_path = "/hamilton"
data_name = "/Ogal_Photos.gdb"
data = gpd.read_file(main_path + data_path + data_name)

# %%
# Check the number of features
print(len(data))

# View the attribute table
print(data.head())
# Out:
# 1268
#                                                 Path  \
# 0  C:\Users\sehamilton\Desktop\imgs\EP-01-13223_0...
# 1  C:\Users\sehamilton\Desktop\imgs\EP-01-13223_0...
# 2  C:\Users\sehamilton\Desktop\imgs\EP-01-13223_0...
# 3  C:\Users\sehamilton\Desktop\imgs\EP-01-13223_0...
# 4  C:\Users\sehamilton\Desktop\imgs\EP-01-13223_0...
#
#                         Name             DateTime  Direction  \
# 0  EP-01-13223_0033_0001.JPG  2018:09:26 12:22:20    -9999.0
# 1  EP-01-13223_0033_0002.JPG  2018:09:26 12:22:23    -9999.0
# 2  EP-01-13223_0033_0003.JPG  2018:09:26 12:22:26    -9999.0
# 3  EP-01-13223_0033_0004.JPG  2018:09:26 12:22:29    -9999.0
# 4  EP-01-13223_0033_0005.JPG  2018:09:26 12:22:32    -9999.0
#
#                                  geometry
# 0  POINT Z (34.58713 -0.14407 1373.21480)
# 1  POINT Z (34.58713 -0.14443 1372.39370)
# 2  POINT Z (34.58716 -0.14478 1371.41490)
# 3  POINT Z (34.58715 -0.14514 1371.45390)
# 4  POINT Z (34.58716 -0.14549 1371.32760)

# %%
data.plot()
plt.show()

# %%
# Open the file:
data_set = gdal.Open(main_path + data_path + '/Ogal.tif')
# Out:
# /home/amir/anaconda3/envs/earth-analytics-python/lib/python3.8/site-packages/osgeo/gdal.py:287: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(

# %%
# As, there are 3 bands, We will store in 3 different variables  
band_1 = data_set.GetRasterBand(1) # red channel  
band_2 = data_set.GetRasterBand(2) # green channel  
band_3 = data_set.GetRasterBand(3) # blue channel

# %%
b1 = band_1.ReadAsArray()  
b2 = band_2.ReadAsArray()  
b3 = band_3.ReadAsArray()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b1 = band_1.ReadAsArray()
#       2 b2 = band_2.ReadAsArray()
#       3 b3 = band_3.ReadAsArray()
#
# File ~/anaconda3/envs/earth-analytics-python/lib/python3.8/site-packages/osgeo/gdal.py:4728, in Band.ReadAsArray(self, xoff, yoff, win_xsize, win_ysize, buf_xsize, buf_ysize, buf_type, buf_obj, resample_alg, callback, callback_data)
#    4723 """ Reading a chunk of a GDAL band into a numpy array. The optional (buf_xsize,buf_ysize,buf_type)
#    4724 parameters should generally not be specified if buf_obj is specified. The array is returned"""
#    4726 from osgeo import gdal_array
# -> 4728 return gdal_array.BandReadAsArray(self, xoff, yoff,
#    4729                                    win_xsize, win_ysize,
#    4730                                    buf_xsize, buf_ysize, buf_type, buf_obj,
# ...

# %%
img_1 = np.dstack((b1, b2, b3))  
f = plt.figure()  
plt.imshow(img_1)  
plt.savefig('Usenge_tiff.png')  
plt.show()
